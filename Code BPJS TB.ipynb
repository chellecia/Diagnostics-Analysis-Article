# %% [markdown]
# ### **Import Dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Load Dataset**

# %% [markdown]
# #### TB20152021_fkrtl

# %%
data1 = pd.read_stata('C:\\Users\\Michelle\\Downloads\\Semester 5\\Analisis Big Data\\BPJS\\Data Sampel Final 2022\\Kontekstual TB\\TB20152021_fkrtl.dta')

# %%
data1.head()
# Out:
#      PSTV01    PSTV02    PSTV15 FKP02             FKL02      FKL03      FKL04  \
# 0  96934726  96934726  0.899331        1000801150000582 2015-01-21 2015-01-21
# 1  11315168  11315168  0.938273        1000801150001076 2015-01-13 2015-01-13
# 2  48014275  20325942  0.998232        1000801160000002 2016-01-02 2016-01-06
# 3  78552717   3459550  1.205653        1000801160000219 2016-01-08 2016-01-08
# 4  48014275  20325942  0.998232        1000801160000321 2016-01-11 2016-01-11
#
#    FKL05     FKL06                FKL07  ... FKL39 FKL40 FKL41 FKL42 FKL43  \
# 0  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         NaN               NaN
# 1  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         NaN               NaN
# 2  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         0.0               0.0
# 3  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         0.0               0.0
# 4  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         0.0               0.0
#
#   FKL44 FKL45 FKL46    FKL47    FKL48
# ...

# %%
data1.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV15', 'FKP02', 'FKL02', 'FKL03', 'FKL04',
#        'FKL05', 'FKL06', 'FKL07', 'FKL08', 'FKL09', 'FKL10', 'FKL11', 'FKL12',
#        'FKL13', 'FKL14', 'FKL15', 'FKL15A', 'FKL16', 'FKL16A', 'FKL17',
#        'FKL17A', 'FKL18', 'FKL18A', 'FKL19', 'FKL19A', 'FKL20', 'FKL21',
#        'FKL22', 'FKL23', 'FKL25', 'FKL26', 'FKL27', 'FKL28', 'FKL29', 'FKL30',
#        'FKL31', 'FKL32', 'FKL33', 'FKL34', 'FKL35', 'FKL36', 'FKL37', 'FKL38',
#        'FKL39', 'FKL40', 'FKL41', 'FKL42', 'FKL43', 'FKL44', 'FKL45', 'FKL46',
#        'FKL47', 'FKL48'],
#       dtype='object')

# %%
# data1[['FKL05','FKL06', 'FKL07']]

# %%
# Menyeleksi baris dengan nilai 'DKI JAKARTA' di kolom 'FKL05'
jakarta_data = data1[data1['FKL05'] == 'DKI JAKARTA'][['FKL05', 'FKL06', 'FKL07']]

# Menampilkan hasil
jakarta_data.head()
# Out:
#               FKL05               FKL06     FKL07
# 195231  DKI JAKARTA  KOTA JAKARTA PUSAT  Vertikal
# 195232  DKI JAKARTA  KOTA JAKARTA PUSAT  Vertikal
# 195233  DKI JAKARTA  KOTA JAKARTA PUSAT  Vertikal
# 195234  DKI JAKARTA  KOTA JAKARTA PUSAT  Vertikal
# 195235  DKI JAKARTA  KOTA JAKARTA PUSAT  Vertikal

# %% [markdown]
# #### TB2021_kepesertaan

# %%
data2 = pd.read_stata('C:\\Users\\Michelle\\Downloads\\Semester 5\\Analisis Big Data\\BPJS\\Data Sampel Final 2022\\Kontekstual TB\\TB2021_kepesertaan.dta')

# %%
data2.head()
# Out:
#       PSTV01     PSTV02     PSTV03   PSTV04     PSTV05       PSTV06    PSTV07  \
# 0   32853965   31945523 1958-11-27    SUAMI  LAKI-LAKI        KAWIN   KELAS I
# 1    8555967    8555967 1936-07-01  PESERTA  LAKI-LAKI        KAWIN   KELAS I
# 2    8797049     249479 1950-07-21    SUAMI  LAKI-LAKI        KAWIN   KELAS I
# 3   83472658   54408870 2012-08-12     ANAK  PEREMPUAN  BELUM KAWIN   KELAS I
# 4  425874326  296852327 2004-12-30     ANAK  LAKI-LAKI  BELUM KAWIN  KELAS II
#
#           PSTV08          PSTV09        PSTV10                     PSTV11  \
# 0            PPU            ACEH   ACEH TENGAH  PEMERINTAH KABUPATEN/KOTA
# 1  BUKAN PEKERJA            ACEH   ACEH TENGAH                      POLRI
# 2  BUKAN PEKERJA            ACEH  ACEH SELATAN  PEMERINTAH KABUPATEN/KOTA
# 3            PPU            ACEH    ACEH BARAT  PEMERINTAH KABUPATEN/KOTA
# 4            PPU  SUMATERA UTARA  TOBA SAMOSIR  PEMERINTAH KABUPATEN/KOTA
#
# ...

# %%
data2.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV15', 'PSTV16', 'PSTV17', 'PSTV18'],
#       dtype='object')

# %%
# # Menyeleksi baris dengan nilai 'DKI JAKARTA' di kolom 'PSTV14'
# jakarta_data2 = data2[data2['PSTV09'] == 'DKI JAKARTA'][['PSTV09', 'PSTV10']]

# # Menampilkan hasil
# jakarta_data2

# %% [markdown]
# #### TB20152021_fkrtldxsekunder

# %%
data3 = pd.read_stata('C:\\Users\\Michelle\\Downloads\\Semester 5\\Analisis Big Data\\BPJS\\Data Sampel Final 2022\\Kontekstual TB\\TB20152021_fkrtldxsekunder.dta')

# %%
data3.head()
# Out:
#               FKL02  FKL24 FKL24A  \
# 0  2603412140001163   H814    H81
# 1  1337801150000108   M199    M19
# 2  1571901150000730  M4909    M49
# 3  3039201150000052   E790    E79
# 4  3376701150000072   N390    N39
#
#                                               FKL24B
# 0               H81 Disorders of vestibular function
# 1                                M19 Other arthrosis
# 2  M49 Spondylopathies in diseases classified els...
# 3  E79 Disorders of purine and pyrimidine metabolism
# 4              N39 Other disorders of urinary system

# %%
data3.columns
# Out:
# Index(['FKL02', 'FKL24', 'FKL24A', 'FKL24B'], dtype='object')

# %% [markdown]
# #### TB20152021_fktpnonkapitasi

# %%
data4 = pd.read_stata('C:\\Users\\Michelle\\Downloads\\Semester 5\\Analisis Big Data\\BPJS\\Data Sampel Final 2022\\Kontekstual TB\\TB20152021_fktpnonkapitasi.dta')

# %%
data4.head()
# Out:
#       PSTV01     PSTV02     PSTV15             PNK02      PNK03      PNK04  \
# 0   93858078   93216423   7.659537  183920215Y000376 2015-02-26 2015-02-26
# 1   93747649  346217457   1.800196   19500915Y000074 2015-09-21 2015-09-23
# 2  359887820   72989971   0.959155  250630919P000299 2019-09-26 2019-09-29
# 3   84126594   84126594   1.110887  326360919P001086 2019-09-09 2019-09-12
# 4   87558937   62126532  32.451832  252721019P001142 2019-10-14 2019-10-17
#
#        PNK05               PNK06     PNK07                      PNK08  ...  \
# 0 2015-02-27    SULAWESI SELATAN     BARRU  PEMERINTAH KABUPATEN/KOTA  ...
# 1 2015-09-23  KALIMANTAN SELATAN     TAPIN  PEMERINTAH KABUPATEN/KOTA  ...
# 2 2019-09-29               PAPUA  JAYAPURA                     TNI AD  ...
# 3 2019-09-12         JAWA TENGAH   REMBANG  PEMERINTAH KABUPATEN/KOTA  ...
# 4 2019-10-17         JAWA TENGAH   KEBUMEN  PEMERINTAH KABUPATEN/KOTA  ...
#
# ...

# %%
data4.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV15', 'PNK02', 'PNK03', 'PNK04', 'PNK05',
#        'PNK06', 'PNK07', 'PNK08', 'PNK09', 'PNK10', 'PNK11', 'PNK12', 'PNK13',
#        'PNK13A', 'PNK14', 'PNK15', 'PNK16', 'PNK17', 'PNK18'],
#       dtype='object')

# %% [markdown]
# #### Merged Dataset

# %%
# Menggunakan 'outer' untuk mempertahankan semua data
merged_data = pd.merge(data1, data2, on=['PSTV01', 'PSTV02', 'PSTV15'], how='outer')
merged_data1 = pd.merge(merged_data, data3, on=['FKL02'], how='outer')
merged_data2 = pd.merge(merged_data1, data4, on=['PSTV01', 'PSTV02', 'PSTV15'], how='outer')

# %%
merged_data2
# Out:
#             PSTV01     PSTV02     PSTV15            FKP02             FKL02  \
# 0         96934726   96934726   0.899331                   1000801150000582
# 1         96934726   96934726   0.899331  29061119P000199  100080120V001491
# 2         96934726   96934726   0.899331                   1000802150000551
# 3         96934726   96934726   0.899331                   1000802150000796
# 4         96934726   96934726   0.899331                   1000803150000360
# ...            ...        ...        ...              ...               ...
# 3549368  383462684  383462684   4.598344              NaN               NaN
# 3549369  416737632  416737632   1.014827              NaN               NaN
# 3549370  376045446  376045446   9.374174              NaN               NaN
# 3549371  428977811  397973863   1.068245              NaN               NaN
# 3549372  293476602  293476602  10.480680              NaN               NaN
#
# ...

# %%
merged_data2.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV15', 'FKP02', 'FKL02', 'FKL03', 'FKL04',
#        'FKL05', 'FKL06', 'FKL07', 'FKL08', 'FKL09', 'FKL10', 'FKL11', 'FKL12',
#        'FKL13', 'FKL14', 'FKL15', 'FKL15A', 'FKL16', 'FKL16A', 'FKL17',
#        'FKL17A', 'FKL18', 'FKL18A', 'FKL19', 'FKL19A', 'FKL20', 'FKL21',
#        'FKL22', 'FKL23', 'FKL25', 'FKL26', 'FKL27', 'FKL28', 'FKL29', 'FKL30',
#        'FKL31', 'FKL32', 'FKL33', 'FKL34', 'FKL35', 'FKL36', 'FKL37', 'FKL38',
#        'FKL39', 'FKL40', 'FKL41', 'FKL42', 'FKL43', 'FKL44', 'FKL45', 'FKL46',
#        'FKL47', 'FKL48', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV16', 'PSTV17', 'PSTV18', 'FKL24', 'FKL24A', 'FKL24B', 'PNK02',
#        'PNK03', 'PNK04', 'PNK05', 'PNK06', 'PNK07', 'PNK08', 'PNK09', 'PNK10',
#        'PNK11', 'PNK12', 'PNK13', 'PNK13A', 'PNK14', 'PNK15', 'PNK16', 'PNK17',
#        'PNK18'],
#       dtype='object')

# %%
merged_data2.isnull().sum()
# Out:
# PSTV01          0
# PSTV02          0
# PSTV15          0
# FKP02        7960
# FKL02        7960
#            ...
# PNK14     1787684
# PNK15     1787684
# PNK16     1787684
# PNK17     1787684
# PNK18     1787684
# Length: 91, dtype: int64

# %%
merged_data2.duplicated().sum()
# Out:
# 8581

# %%
# Menghapus baris duplikat
merged_data2 = merged_data2.drop_duplicates()

# Mengecek ulang jumlah baris setelah penghapusan duplikat
print("Jumlah baris setelah menghapus duplikat:", merged_data2.shape[0])
# Out:
# Jumlah baris setelah menghapus duplikat: 3540792

# %%
jakarta_data = merged_data2[merged_data2['PSTV09'].str.contains("DKI JAKARTA", case=False, na=False)]

# %%
jakarta_data
# Out:
#             PSTV01     PSTV02      PSTV15 FKP02             FKL02      FKL03  \
# 22180    290494318  290494318   18.118801        101830120V000364 2020-01-02
# 22181    290494318  290494318   18.118801        101830120V006915 2020-01-16
# 22182    290494318  290494318   18.118801        101830120V011095 2020-01-23
# 22183    290494318  290494318   18.118801        101830120V015224 2020-01-30
# 22184    290494318  290494318   18.118801        101830220V004679 2020-02-10
# ...            ...        ...         ...   ...               ...        ...
# 3549190   14803690   59323977    5.843364   NaN               NaN        NaT
# 3549245  358141730   88121078   72.662239   NaN               NaN        NaT
# 3549280  451881662  451881662  163.995117   NaN               NaN        NaT
# 3549296    5986317  364596827    1.449504   NaN               NaN        NaT
# 3549321  443466249  302053760  152.691956   NaN               NaN        NaT
#
# ...

# %% [markdown]
# #### Filter Dataset

# %%
# Filter hanya kolom yang diinginkan dari jakarta_data
filtered_data = jakarta_data[['PSTV03','PSTV05','FKL15', 'FKL15A', 'FKL16','FKL16A', 'FKL17', 'FKL17A', 'FKL18', 'FKL18A', 'PNK13', 'PNK13A', 'PNK14', 'PNK15', 'PNK16']]

# Menampilkan hasil
filtered_data
# Out:
#             PSTV03     PSTV05  \
# 22180   1990-08-21  PEREMPUAN
# 22181   1990-08-21  PEREMPUAN
# 22182   1990-08-21  PEREMPUAN
# 22183   1990-08-21  PEREMPUAN
# 22184   1990-08-21  PEREMPUAN
# ...            ...        ...
# 3549190 2010-09-27  LAKI-LAKI
# 3549245 2017-07-31  PEREMPUAN
# 3549280 1968-06-03  LAKI-LAKI
# 3549296 1991-01-02  PEREMPUAN
# 3549321 1999-10-22  PEREMPUAN
#
#                                                     FKL15 FKL15A  FKL16  \
# 22180                       R10 Abdominal and pelvic pain    R10    R10
# 22181                                       M54 Dorsalgia    M54   M545
# 22182    M76 Enthesopathies of lower limb, excluding foot    M76  M7605
# 22183    M76 Enthesopathies of lower limb, excluding foot    M76  M7605
# 22184    M76 Enthesopathies of lower limb, excluding foot    M76  M7605
# ...                                                   ...    ...    ...
# 3549190                                               NaN    NaN    NaN
# ...

# %%
# Cek jumlah NaN di setiap kolom
nan_counts = filtered_data.isna().sum()

# Menampilkan hasil
print("Jumlah NaN di setiap kolom:")
nan_counts
# Out:
# Jumlah NaN di setiap kolom:
# PSTV03        0
# PSTV05        0
# FKL15       171
# FKL15A      171
# FKL16       171
# FKL16A      171
# FKL17       171
# FKL17A      171
# FKL18       171
# FKL18A      171
# PNK13     55759
# PNK13A    55759
# PNK14     55759
# PNK15     55759
# PNK16     55759
# dtype: int64

# %%
# Menghapus baris yang memiliki nilai NaN
filtered_data = filtered_data.dropna()

# Menampilkan data setelah penghapusan NaN
print("Data setelah menghapus baris yang mengandung NaN:")
filtered_data
# Out:
# Data setelah menghapus baris yang mengandung NaN:
#             PSTV03     PSTV05 FKL15 FKL15A FKL16 FKL16A  \
# 27203   1975-07-08  PEREMPUAN  9999
# 27204   1975-07-08  PEREMPUAN  9999
# 27205   1975-07-08  PEREMPUAN  9999
# 27206   1975-07-08  PEREMPUAN  9999
# 27207   1975-07-08  PEREMPUAN  9999
# ...            ...        ...   ...    ...   ...    ...
# 3480173 1989-09-24  PEREMPUAN  9999
# 3480174 1989-09-24  PEREMPUAN  9999
# 3480175 1989-09-24  PEREMPUAN  9999
# 3480176 1989-09-24  PEREMPUAN  9999
# 3480177 1989-09-24  PEREMPUAN  9999
#
#                                                      FKL17 FKL17A FKL18  \
# 27203    Z09 Follow-up examination after treatment for ...    Z09  Z097
# 27204    Z09 Follow-up examination after treatment for ...    Z09  Z097
# 27205    Z09 Follow-up examination after treatment for ...    Z09  Z097
# 27206    Z09 Follow-up examination after treatment for ...    Z09  Z097
# 27207    Z09 Follow-up examination after treatment for ...    Z09  Z097
# ...

# %%
# Memfilter data di kolom FKL17A agar hanya berisi nilai A15, A16, A17, A18, dan A19
filtered_data_TB = filtered_data[filtered_data['FKL17A'].isin(['A15', 'A16', 'A17', 'A18', 'A19'])]

# Mengecek hasilnya
filtered_data_TB
# Out:
#             PSTV03     PSTV05                               FKL15 FKL15A  \
# 745264  1965-12-23  PEREMPUAN  R52 Pain, not elsewhere classified    R52
# 745265  1965-12-23  PEREMPUAN  R52 Pain, not elsewhere classified    R52
# 745266  1965-12-23  PEREMPUAN  R52 Pain, not elsewhere classified    R52
# 745267  1965-12-23  PEREMPUAN  R52 Pain, not elsewhere classified    R52
# 745268  1965-12-23  PEREMPUAN  R52 Pain, not elsewhere classified    R52
# ...            ...        ...                                 ...    ...
# 3091613 1968-09-05  PEREMPUAN        E11 Type 2 diabetes mellitus    E11
# 3091614 1968-09-05  PEREMPUAN        E11 Type 2 diabetes mellitus    E11
# 3091615 1968-09-05  PEREMPUAN        E11 Type 2 diabetes mellitus    E11
# 3480140 1989-01-22  PEREMPUAN           E04 Other nontoxic goitre    E04
# 3480141 1989-01-22  PEREMPUAN           E04 Other nontoxic goitre    E04
#
#         FKL16                                   FKL16A  \
# ...

# %% [markdown]
# #### Rename Kolom

# %%
# Melakukan rename kolom sesuai dengan yang diinginkan
filtered_data_TB = filtered_data_TB.rename(columns={
    'PSTV03': 'Tanggal Lahir Peserta',
    'PSTV05': 'Jenis Kelamin',
    'FKL15': 'Kode Diagnosis Masuk ICD 10',
    'FKL15A': 'Kode Diagnosis Masuk ICD 10 (3 Digit)',
    'FKL16': 'Kode ICD 10 diagnosis masuk FKRTL (3-6digit)',
    'FKL16A': 'Nama Diagnosis Masuk (3-6 Digit)',
    'FKL17': 'Kode dan nama diagnosis primer ICD 10 (3 digit) ',
    'FKL17A': 'Kode diagnosis primer ICD 10 (3 digit)',
    'FKL18': 'Kode ICD 10 diagnosis primer FKRTL (3-6digit) ',
    'FKL18A': 'Nama diagnosis primer FKRTL (3-6digit) ',
    'PNK13': 'Kode dan Nama Diagnosis ICD-10 (3 Digit)',
    'PNK13A': 'Kode Diagnosis ICD-10 (3 Digit)',
    'PNK14': 'Kode Diagnosis (3-5 Digit)',
    'PNK15': 'Nama Diagnosis',
    'PNK16': 'Nama Tindakan'
})

# Mengecek hasilnya
print(filtered_data_TB.columns)
# Out:
# Index(['Tanggal Lahir Peserta', 'Jenis Kelamin', 'Kode Diagnosis Masuk ICD 10',
#        'Kode Diagnosis Masuk ICD 10 (3 Digit)',
#        'Kode ICD 10 diagnosis masuk FKRTL (3-6digit)',
#        'Nama Diagnosis Masuk (3-6 Digit)',
#        'Kode dan nama diagnosis primer ICD 10 (3 digit) ',
#        'Kode diagnosis primer ICD 10 (3 digit)',
#        'Kode ICD 10 diagnosis primer FKRTL (3-6digit) ',
#        'Nama diagnosis primer FKRTL (3-6digit) ',
#        'Kode dan Nama Diagnosis ICD-10 (3 Digit)',
#        'Kode Diagnosis ICD-10 (3 Digit)', 'Kode Diagnosis (3-5 Digit)',
#        'Nama Diagnosis', 'Nama Tindakan'],
#       dtype='object')

# %%
filtered_data_TB.head()
# Out:
#        Tanggal Lahir Peserta Jenis Kelamin  \
# 745264            1965-12-23     PEREMPUAN
# 745265            1965-12-23     PEREMPUAN
# 745266            1965-12-23     PEREMPUAN
# 745267            1965-12-23     PEREMPUAN
# 745268            1965-12-23     PEREMPUAN
#
#                Kode Diagnosis Masuk ICD 10  \
# 745264  R52 Pain, not elsewhere classified
# 745265  R52 Pain, not elsewhere classified
# 745266  R52 Pain, not elsewhere classified
# 745267  R52 Pain, not elsewhere classified
# 745268  R52 Pain, not elsewhere classified
#
#        Kode Diagnosis Masuk ICD 10 (3 Digit)  \
# 745264                                   R52
# 745265                                   R52
# 745266                                   R52
# 745267                                   R52
# 745268                                   R52
#
#        Kode ICD 10 diagnosis masuk FKRTL (3-6digit)  \
# 745264                                         R529
# ...

# %%
# Mengambil kode unik dari kolom 'Kode Diagnosis ICD-10 (3 Digit)'
unique_codes = filtered_data_TB['Kode Diagnosis ICD-10 (3 Digit)'].unique()

# Menampilkan kode-kode unik tersebut
print(unique_codes)
# Out:
# ['E11' 'O41' 'O80' 'A68' 'I10' 'Z34' 'Z30' 'O63' 'O60' 'O45' 'Z36' 'E14'
#  'O72' 'O68' 'Z33']

# %% [markdown]
# **Penjelesan Kode ICD-10**
#
# E11 - Diabetes Mellitus Tipe 2
#
#
# O75 - Komplikasi yang terkait dengan persalinan dan kelahiran
#
#
# O80 - Persalinan tunggal, normal (tidak ada komplikasi)
#
# Z36 - Pengawasan selama kehamilan untuk evaluasi pertumbuhan janin
#
# Z30 - Kontrasepsi dan pengaturan keluarga lainnya
#
# O41 - Komplikasi plasenta dan kantung ketuban
#
# Z39 - Pemantauan pasca persalinan untuk ibu
#
# A68 - Infeksi yang disebabkan oleh Rickettsia (misalnya, demam berbintik)
#
# I10 - Hipertensi Esensial (primer)
#
# Z34 - Pengawasan selama kehamilan pada kehamilan tunggal
#
# O42 - Perdarahan dari plasenta atau kantung ketuban
#
# O99 - Gangguan lain terkait kehamilan, persalinan, dan pasca-persalinan
#
# A91 - Demam Berdarah Dengue
#
# E14 - Diabetes Mellitus Tipe 2 (tanpa komplikasi)
#
# O63 - Persalinan lama
#
# O00 - Kehamilan Ektopik
#
# Z37 - Lahir hidup dan mati
#
# O60 - Persalinan prematur
#
# O45 - Plasenta Previa
#
# O72 - Komplikasi selama persalinan
#
# N72 - Peradangan dan infeksi organ reproduksi wanita
#
# P08 - Bayi lahir prematur
#
# Z32 - Pengawasan kehamilan dan pengujian untuk kehamilan
#
# Z92 - Riwayat medis sebelumnya
#
# Z35 - Pengawasan atas kehamilan dengan risiko tinggi
#
# A01 - Demam tifoid dan paratifoid
#
# O68 - Komplikasi selama persalinan karena kelainan posisi janin
#
# Z33 - Kehamilan tanpa komplikasi

# %% [markdown]
# #### Visualisasi

# %%
# Menghitung frekuensi dari setiap kode dalam kolom 'Kode Diagnosis ICD-10 (3 Digit)'
top_codes = filtered_data_TB['Kode Diagnosis ICD-10 (3 Digit)'].value_counts().head(5)

# Mengganti label kode diagnosis dengan deskripsi lengkap
labels = [
    'E11: Diabetes Mellitus Tipe 2',
    'I10: Hipertensi Esensial (primer)',
    'E14: Diabetes Mellitus Tipe 2 (tanpa komplikasi)',
    'Z30: Kontrasepsi dan pengaturan keluarga',
    'O80: Persalinan tunggal, normal'
]

# Warna khusus untuk setiap sektor
colors = ['#D56C42', '#FF7F50', '#F4A300', '#E64A19', '#D32F2F']

# Menambahkan efek explode untuk bagian dengan frekuensi tertinggi
explode = [0.1 if i == 0 else 0 for i in range(len(top_codes))]

# Membuat pie chart
plt.figure(figsize=(10, 8))
plt.pie(
    top_codes, 
    labels=labels, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=colors, 
    explode=explode,
    shadow=True,   # Menambahkan bayangan
    wedgeprops={'edgecolor': 'black'}  # Membuat garis pembatas antar sektor
)

# Menambahkan judul
plt.title('Distribusi 5 Kode Diagnosis ICD-10 Teratas', fontsize=16, fontweight='bold')

# Menampilkan plot
plt.show()

# %%
filtered_data_TB.columns
# Out:
# Index(['Tanggal Lahir Peserta', 'Jenis Kelamin', 'Kode Diagnosis Masuk ICD 10',
#        'Kode Diagnosis Masuk ICD 10 (3 Digit)',
#        'Kode ICD 10 diagnosis masuk FKRTL (3-6digit)',
#        'Nama Diagnosis Masuk (3-6 Digit)',
#        'Kode dan nama diagnosis primer ICD 10 (3 digit) ',
#        'Kode diagnosis primer ICD 10 (3 digit)',
#        'Kode ICD 10 diagnosis primer FKRTL (3-6digit) ',
#        'Nama diagnosis primer FKRTL (3-6digit) ',
#        'Kode dan Nama Diagnosis ICD-10 (3 Digit)',
#        'Kode Diagnosis ICD-10 (3 Digit)', 'Kode Diagnosis (3-5 Digit)',
#        'Nama Diagnosis', 'Nama Tindakan'],
#       dtype='object')

# %%
# Mengonversi "Tanggal Lahir Peserta" menjadi usia
filtered_data_TB['Tanggal Lahir Peserta'] = pd.to_datetime(filtered_data_TB['Tanggal Lahir Peserta'])
current_year = pd.to_datetime('today').year
filtered_data_TB['Usia'] = current_year - filtered_data_TB['Tanggal Lahir Peserta'].dt.year

# Mengelompokkan usia ke dalam kategori
bins = [0, 18, 30, 45, 60, 100]
labels = ['0-18', '19-30', '31-45', '46-60', '60+']
filtered_data_TB['Kelompok Usia'] = pd.cut(filtered_data_TB['Usia'], bins=bins, labels=labels, right=False)

# Menghitung distribusi kode diagnosis ICD-10 berdasarkan kelompok usia
age_group_distribution = filtered_data_TB.groupby(['Kelompok Usia', 'Kode Diagnosis ICD-10 (3 Digit)']).size().unstack()

# Memilih 5 kode diagnosis teratas berdasarkan total jumlah kasus
top_codes = age_group_distribution.sum().nlargest(5)
age_group_distribution_top = age_group_distribution[top_codes.index]

# Menggunakan colormap 'Oranges' dengan nilai tinggi artinya warna lebih gelap
cmap = plt.cm.Oranges_r  # .r membalikkan colormap

# Menampilkan stacked bar plot
plt.figure(figsize=(10, 8))
age_group_distribution_top.plot(kind='bar', stacked=True, figsize=(10, 8), colormap=cmap, edgecolor='black')

# Menambahkan grid, judul, dan label
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Grid garis putus-putus
plt.title('Distribusi Kode Diagnosis ICD-10 Teratas Berdasarkan Kelompok Usia', fontsize=16, fontweight='bold')
plt.xlabel('Kelompok Usia', fontsize=14)
plt.ylabel('Jumlah Kasus', fontsize=14)
plt.xticks(rotation=45)

# Menambahkan annotasi pada setiap bar untuk menunjukkan jumlah kasus
for i, bar_container in enumerate(plt.gca().containers):
    for bar in bar_container:
        height = bar.get_height()
        if height > 0:
            plt.gca().text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_y() + height / 2,
                f'{int(height)}',
                ha='center',
                va='center',
                fontsize=10,
                color='white'
            )

# Menampilkan plot dengan layout rapi
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Michelle\AppData\Local\Temp\ipykernel_58096\3036271711.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_group_distribution = filtered_data_TB.groupby(['Kelompok Usia', 'Kode Diagnosis ICD-10 (3 Digit)']).size().unstack()

# %%
# Menggunakan value_counts() untuk distribusi jumlah jenis kelamin
gender_distribution = filtered_data_TB['Jenis Kelamin'].value_counts()
print(gender_distribution)
# Out:
# Jenis Kelamin
# PEREMPUAN    282
# LAKI-LAKI     92
# Name: count, dtype: int64

# %%
# Mengambil distribusi jenis kelamin
gender_distribution = filtered_data_TB['Jenis Kelamin'].value_counts()

# Mengatur warna gradien terbalik (dari gelap ke terang)
colors = sns.color_palette("OrRd_r", len(gender_distribution))  # "OrRd_r" untuk membalik palet warna

# Plot bar dengan ikon gender
plt.figure(figsize=(8, 6))
bars = plt.bar(gender_distribution.index, gender_distribution.values, color=colors)

# Menambahkan label dan judul
plt.title('Distribusi Jenis Kelamin', fontsize=16, fontweight='bold')
plt.xlabel('Jenis Kelamin')
plt.ylabel('Jumlah')
plt.xticks(rotation=0)

# Menambahkan ikon gender dalam grid
for i, (index, value) in enumerate(gender_distribution.items()):
    icon = '♂' if index == 'LAKI-LAKI' else '♀'  # Sesuaikan dengan kategori
    # Mengurangi posisi vertikal ikon agar tetap dalam grid
    plt.text(i, value - 0.02 * max(gender_distribution.values), icon, ha='center', va='top', fontsize=18)

# Menampilkan plot
plt.show()
